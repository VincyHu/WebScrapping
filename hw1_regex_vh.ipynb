# %% [markdown]
# regex
# Use the attached “mock_data.csv” file for this part (mock_data.csv).
#
# Each of the following tasks is independent and will be performed on newly opened "mock_data.csv". Changes you make to the header line in the file is optional (meaning your output can keep the header line as is, can remove it or change it to any shape). For this part of the assignment, you are required to comment each section's number prior to it. Please supply the regex search + replace term and print output:
#
#
#
# 1 - To transform the column birthday from European to US data format while leaving the rest as is.
#
# 2 - To strip everything BUT the email column.
#
# 3 - To convert all rows to "name [TAB] birthday" only (and strip the rest).  The birthday column should be in the US format. ([TAB]s will allow you to copy and pass its result into excel.)
#
# 4 - To strip everything BUT lat_long AND reorder its entries to be "long [TAB] lat".  ([TAB]s will allow you to copy and pass its result into excel.)

# %% [markdown]
# # import library to do regex

# %%
import re

# %% [markdown]
# # open and read data file

# %%
# import by normal .read()
text_file = open("mock_data.csv", mode = 'r', encoding = 'utf-8')
lines = text_file.read()
print(lines)
# Out:
# birthday,phone,names,lat_long,email,zip,city
# 05.07.2020,1-560-294-4480,Leslie H. Howard,"-80.7931, 157.73725",magna.Nam@Praesentinterdumligula.com,05-449,Campina Grande
# 06.11.2019,1-616-403-7121,Kyra T. Wynn,"-54.65661, 87.93458",amet.ornare@uterosnon.net,1975,Bagh
# 23.11.2020,1-258-160-9496,Darius G. Huff,"-56.23283, -116.1583",ipsum@erat.co.uk,24192,Conca Casale
# 07.05.2020,1-129-425-6705,Flynn M. Rodriguez,"50.02477, -93.02564",nunc.est.mollis@auctor.com,6311,Uyo
# 25.09.2020,1-715-932-5611,Damon K. Potts,"34.94064, 91.87029",neque.venenatis@Phasellus.ca,26531,Lahore
# 30.12.2019,1-488-594-4480,Odessa U. Stewart,"41.01394, 96.36819",Proin.mi@a.co.uk,40738,Namen
# 04.03.2019,1-693-871-0017,Ruby M. Noble,"75.21109, -148.67016",gravida.non.sollicitudin@odioNam.net,968589,Sevilla
# 17.12.2020,1-337-498-7475,Hadassah W. Dale,"32.72148, -122.01392",Cras@dictum.co.uk,5375,Bella
# ...

# %%
# import by for...in... loop
data_file = open("mock_data.csv", mode = 'r', encoding = 'utf-8')
for line in data_file:
    print(line,)
    
data_file.close()
# Out:
# birthday,phone,names,lat_long,email,zip,city
#
# 05.07.2020,1-560-294-4480,Leslie H. Howard,"-80.7931, 157.73725",magna.Nam@Praesentinterdumligula.com,05-449,Campina Grande
#
# 06.11.2019,1-616-403-7121,Kyra T. Wynn,"-54.65661, 87.93458",amet.ornare@uterosnon.net,1975,Bagh
#
# 23.11.2020,1-258-160-9496,Darius G. Huff,"-56.23283, -116.1583",ipsum@erat.co.uk,24192,Conca Casale
#
# 07.05.2020,1-129-425-6705,Flynn M. Rodriguez,"50.02477, -93.02564",nunc.est.mollis@auctor.com,6311,Uyo
#
# 25.09.2020,1-715-932-5611,Damon K. Potts,"34.94064, 91.87029",neque.venenatis@Phasellus.ca,26531,Lahore
#
# 30.12.2019,1-488-594-4480,Odessa U. Stewart,"41.01394, 96.36819",Proin.mi@a.co.uk,40738,Namen
#
# 04.03.2019,1-693-871-0017,Ruby M. Noble,"75.21109, -148.67016",gravida.non.sollicitudin@odioNam.net,968589,Sevilla
#
# 17.12.2020,1-337-498-7475,Hadassah W. Dale,"32.72148, -122.01392",Cras@dictum.co.uk,5375,Bella
#
# ...

# %%
## Q1 To transform the column birthday from European to US data format while leaving the rest as is.
